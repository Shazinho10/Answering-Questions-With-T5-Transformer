# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/MyDrive/T5 tests on different data/QNA'
# Out:
# /content/drive/MyDrive/T5 tests on different data/QNA

# %%
#!pip install Sentencepiece
#!pip install transformers

# %%
from data_extraction import extract_test_data
from inference import answer_generator

import torch
import warnings
warnings.filterwarnings('ignore')

from transformers import (AdamW, 
                          T5ForConditionalGeneration,
                          T5Tokenizer,
                          get_linear_schedule_with_warmup)

# %%
data_path = '/content/drive/MyDrive/T5 tests on different data/QNA/data/BioASQ/BioASQ-test-factoid-5b-5.json'
df = extract_test_data(data_path)
question = df.iloc[10].questions
context = df.iloc[10].context

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
model = T5ForConditionalGeneration.from_pretrained('t5-small', from_tf=False, return_dict=True)
# Out:
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/242M [00:00<?, ?B/s]

# %%
model.load_state_dict(torch.load('new_model.pt', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
answer_generator(tokenizer, model, question, context)
# Out:
# Answer:  ribosomal protein genes
